# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pickle
from sklearn.ensemble import BaggingRegressor

# %%
df=pd.read_csv('CAR DETAILS.csv')
df.head()
# Out:
#                                    name  year  selling_price  km_driven  \
# 0        Ambassador CLASSIC 1500 DSL AC  2005         120000      50000
# 1        Ambassador CLASSIC 1500 DSL AC  2005         120000      50000
# 2           Ambassador Classic 2000 Dsz  2002          50000     120000
# 3  Ambassador Grand 1800 ISZ MPFI PW CL  2012         430000      50000
# 4                      Audi A4 1.8 TFSI  2012        1200000      60000
#
#      fuel seller_type transmission                 owner
# 0  Diesel  Individual       Manual          Second Owner
# 1  Diesel  Individual       Manual          Second Owner
# 2  Diesel  Individual       Manual  Fourth & Above Owner
# 3  Petrol  Individual       Manual          Second Owner
# 4  Petrol  Individual    Automatic           Third Owner

# %%
df.describe().T
# Out:
#                 count           mean            std      min        25%  \
# year           4340.0    2013.090783       4.215344   1992.0    2011.00
# selling_price  4340.0  504127.311751  578548.736139  20000.0  208749.75
# km_driven      4340.0   66215.777419   46644.102194      1.0   35000.00
#
#                     50%       75%        max
# year             2014.0    2016.0     2020.0
# selling_price  350000.0  600000.0  8900000.0
# km_driven       60000.0   90000.0   806599.0

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 763

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#                                    name  year  selling_price  km_driven  \
# 0        Ambassador CLASSIC 1500 DSL AC  2005         120000      50000
# 2           Ambassador Classic 2000 Dsz  2002          50000     120000
# 3  Ambassador Grand 1800 ISZ MPFI PW CL  2012         430000      50000
# 4                      Audi A4 1.8 TFSI  2012        1200000      60000
# 5                       Audi A4 2.0 TDI  2011        1295000      58000
#
#      fuel seller_type transmission                 owner
# 0  Diesel  Individual       Manual          Second Owner
# 2  Diesel  Individual       Manual  Fourth & Above Owner
# 3  Petrol  Individual       Manual          Second Owner
# 4  Petrol  Individual    Automatic           Third Owner
# 5  Diesel      Dealer    Automatic           First Owner

# %%
df["company"] = df.name.apply(lambda x: ' '.join(x.split(' ')[:1]))
df.head()
# Out:
#                                    name  year  selling_price  km_driven  \
# 0        Ambassador CLASSIC 1500 DSL AC  2005         120000      50000
# 2           Ambassador Classic 2000 Dsz  2002          50000     120000
# 3  Ambassador Grand 1800 ISZ MPFI PW CL  2012         430000      50000
# 4                      Audi A4 1.8 TFSI  2012        1200000      60000
# 5                       Audi A4 2.0 TDI  2011        1295000      58000
#
#      fuel seller_type transmission                 owner     company
# 0  Diesel  Individual       Manual          Second Owner  Ambassador
# 2  Diesel  Individual       Manual  Fourth & Above Owner  Ambassador
# 3  Petrol  Individual       Manual          Second Owner  Ambassador
# 4  Petrol  Individual    Automatic           Third Owner        Audi
# 5  Diesel      Dealer    Automatic           First Owner        Audi

# %%
df['company'].value_counts()
# Out:
# Maruti           1072
# Hyundai           637
# Mahindra          328
# Tata              308
# Ford              220
# Honda             216
# Toyota            170
# Chevrolet         151
# Renault           110
# Volkswagen         93
# Nissan             52
# Skoda              49
# Fiat               32
# Audi               31
# Datsun             29
# BMW                25
# Mercedes-Benz      21
# Mitsubishi          5
# Land                5
# Jaguar              5
# Volvo               4
# Ambassador          3
# Jeep                3
# OpelCorsa           2
# MG                  2
# Isuzu               1
# Force               1
# Daewoo              1
# Kia                 1
# Name: company, dtype: int64

# %%
df
# Out:
#                                       name  year  selling_price  km_driven  \
# 0           Ambassador CLASSIC 1500 DSL AC  2005         120000      50000
# 2              Ambassador Classic 2000 Dsz  2002          50000     120000
# 3     Ambassador Grand 1800 ISZ MPFI PW CL  2012         430000      50000
# 4                         Audi A4 1.8 TFSI  2012        1200000      60000
# 5                          Audi A4 2.0 TDI  2011        1295000      58000
# ...                                    ...   ...            ...        ...
# 4335   Volkswagen Vento Petrol Highline AT  2011         300000      70000
# 4336                 Volvo V40 D3 R Design  2018        1975000      21000
# 4337       Volvo XC 90 D5 Inscription BSIV  2017        4500000      80000
# 4338                 Volvo XC60 D3 Kinetic  2012        1750000     115992
# 4339             Volvo XC60 D5 Inscription  2014        2000000     130000
#
#         fuel seller_type transmission                 owner     company
# 0     Diesel  Individual       Manual          Second Owner  Ambassador
# 2     Diesel  Individual       Manual  Fourth & Above Owner  Ambassador
# 3     Petrol  Individual       Manual          Second Owner  Ambassador
# 4     Petrol  Individual    Automatic           Third Owner        Audi
# 5     Diesel      Dealer    Automatic           First Owner        Audi
# ...      ...         ...          ...                   ...         ...
# 4335  Petrol  Individual    Automatic           Third Owner  Volkswagen
# 4336  Diesel      Dealer    Automatic           First Owner       Volvo
# 4337  Diesel  Individual    Automatic           First Owner       Volvo
# 4338  Diesel      Dealer    Automatic           Third Owner       Volvo
# 4339  Diesel  Individual    Automatic           First Owner       Volvo
#
# [3577 rows x 9 columns]

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# #### Separting Categorical and Numerical Columns

# %%
cat_cols=df.dtypes[df.dtypes=='object'].index
num_cols=df.dtypes[df.dtypes!='object'].index
print(num_cols,'\n',cat_cols)
# Out:
# Index(['year', 'selling_price', 'km_driven'], dtype='object')
#  Index(['name', 'fuel', 'seller_type', 'transmission', 'owner', 'company'], dtype='object')

# %%
for i in num_cols:
    print(f'Feature {i} | Unique Count {df[i].nunique()}')
# Out:
# Feature year | Unique Count 27
# Feature selling_price | Unique Count 445
# Feature km_driven | Unique Count 770

# %%
for i in cat_cols:
    print(f'Feature {i} | Unique Count {df[i].nunique()}')
# Out:
# Feature name | Unique Count 1491
# Feature fuel | Unique Count 5
# Feature seller_type | Unique Count 3
# Feature transmission | Unique Count 2
# Feature owner | Unique Count 5
# Feature company | Unique Count 29

# %%
plt.figure(figsize=(12,11))
for i in range (len(cat_cols)):
    plt.subplot(3,2,i+1)
    sns.countplot(x=df[cat_cols[i]])
    plt.xticks(rotation=45)
    plt.title(f'Countplot for {cat_cols[i]}')
plt.tight_layout(h_pad=2.0)
plt.show()

# %% [markdown]
# ### Insights
# 1) Most of the used cars available are belongs to petrol and Diesel category
# 2) All most all the cars transmisson are of Manually operated
# 3) Available cars are more likely to be First and 2nd Hand users only
# 4) Sellers prefer to sell their car directly to customers ( individual ) compare to Dealer or Trusted Dealer
# 5) Maruti, Hyundai, Mahindra, Tata are most of used cars available in market compare to other brands of cars

# %% [markdown]
# Variation of Cat_cols wrt selling_price - Boxplot

# %%
plt.figure(figsize=(10,8))
for i in range(len(num_cols)):
    plt.subplot(2,2,i+1)
    sns.histplot(data=df,x=num_cols[i],kde=True,hue='seller_type')
    plt.xticks(rotation=0)
#plt.savefig('Histoplot ')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights
# 1) Most of the available used cars released after 2005
# 2) 90 percentage of cars are sold for less than 1500000
# 3) Sellers prefers to sell their cars before reaching 200000 km
# 4) Its clearly indicates individual sellers are more available in the market compare to Third party sellers

# %%
plt.figure(figsize=(10,4))
for i in range(len(num_cols)):
    plt.subplot(1,3,i+1)
    sns.boxplot(data=df,x=num_cols[i])  
    plt.title(f'Box Plot for {num_cols[i]}')
plt.savefig("Box Plot")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df,hue='transmission')
plt.savefig("Paiplot for continuous variable")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Treating Outliers

# %%
df.describe(percentiles=[0.01,0.02,0.03,0.04,0.97,0.98,0.99]).T.iloc[:,3:]
# Out:
#                    min        1%       2%       3%       4%       50%  \
# year            1992.0   2000.00   2003.0   2004.0   2005.0    2013.0
# selling_price  20000.0  51786.64  60000.0  70000.0  75000.0  350000.0
# km_driven          1.0   1744.08   5000.0   6525.2  10000.0   60000.0
#
#                      97%        98%        99%        max
# year              2019.0     2019.0     2020.0     2020.0
# selling_price  1497200.0  1800000.0  2675000.0  8900000.0
# km_driven       170000.0   193440.0   223158.4   806599.0

# %%
df['selling_price']=np.where(df['selling_price']<51786.64,51786.64,	df['selling_price'])
df['km_driven']=np.where(df['km_driven']>223158.4,223158.4,df['km_driven'])

# %%
df['selling_price']=np.where(df['selling_price']> 2675000.0,2675000.0,	df['selling_price'])
df['km_driven']=np.where(df['km_driven']< 1744.08,1744.08,df['km_driven'])

# %%
df.describe(percentiles=[0.01,0.02,0.03,0.04,0.97,0.98,0.99]).T.iloc[:,3:]
# Out:
#                     min          1%       2%       3%       4%       50%  \
# year            1992.00   2000.0000   2003.0   2004.0   2005.0    2013.0
# selling_price  51786.64  51948.7936  60000.0  70000.0  75000.0  350000.0
# km_driven       1744.08   1754.6592   5000.0   6525.2  10000.0   60000.0
#
#                      97%        98%          99%        max
# year              2019.0     2019.0     2020.000     2020.0
# selling_price  1497200.0  1800000.0  2675000.000  2675000.0
# km_driven       170000.0   193440.0   223038.016   223158.4

# %%
df['year'].value_counts()
df['year'].nunique()
# Out:
# 27

# %% [markdown]
# We dont treat year for outliers as it is a categorical columns with 27 different values.

# %% [markdown]
# ### Correlation Map

# %%
corr=df[num_cols].corr()
sns.heatmap(corr,cmap='coolwarm',annot=True)
plt.savefig('Correlation Graph')
plt.show()

# %% [markdown]
# ### Encoding

# %%
categorical_columns=['name','company' ,'fuel', 'seller_type', 'transmission', 'owner']

# %%
transformer = ColumnTransformer([('encoder', OneHotEncoder(), categorical_columns)], remainder='passthrough')

# %%
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(),
#                                  ['name', 'company', 'fuel', 'seller_type',
#                                   'transmission', 'owner'])])

# %%
plt.figure(figsize=(12,11))
for i in range (len(categorical_columns)):
    plt.subplot(3,2,i+1)
    sns.countplot(x=df[categorical_columns[i]])
    plt.xticks(rotation=90)
    plt.title(f'Countplot for {categorical_columns[i]}')
plt.tight_layout(h_pad=2.0)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_14692/359437421.py:7: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout(h_pad=2.0)

# %% [markdown]
# #### Select x and y

# %%
X=transformer.fit_transform(df.drop('selling_price',axis =1))
y=df['selling_price'].values

# %%
# Splitting data into 70% train and 30% test sets								
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=499)

# %% [markdown]
# #### Creating a function to evaluate the model

# %%
#training random forest model
regressor =RandomForestRegressor()
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
def mscore(model):
    print("TrainingScore",model.score(X_train,y_train))
    print("TestingScore",model.score(X_test,y_test))

# %%
mscore(regressor)
# Out:
# TrainingScore 0.9657670141358834
# TestingScore 0.7762954466867877

# %%
# Create a Linear Regression model
linear_regressor = LinearRegression()

# Train the model on the training data
linear_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = linear_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
mscore(linear_regressor)
# Out:
# TrainingScore 0.585701130379385
# TestingScore 0.564716092662648

# %% [markdown]
# Saving model

# %%
pipeline = (transformer,regressor)
with open('car_pipeline.pkl','wb') as file:
    pickle.dump(pipeline,file)
